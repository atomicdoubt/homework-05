# %% [markdown]
# # A WeatherAPI alternative

# %% [markdown]
# #### Question 1: Open Meteo or Tomorrow?
#
# I'm going to start with Tomorrow, since the way to request Open Meteo data seems to use a lot of new libraries that look complicated, whereas Tomorrow looks more familiar. Open Meteo also looked too fancy and it was less obvious how to get a simple url

# %% [markdown]
# #### Question 2: URL to documentation
#
# I think it's https://docs.tomorrow.io/reference/welcome, but then there are individual pages for different things you can do. The weather forecast doc is: https://docs.tomorrow.io/reference/weather-forecast

# %% [markdown]
# #### Question 3: Request for current weather in Urbana, IL

# %%
from dotenv import load_dotenv
import os

load_dotenv()

API_KEY_TOMORROW = os.getenv("API_KEY_TOMORROW")

# %%
baseurl = 'https://api.tomorrow.io/v4/weather/'

import requests
from prettyprinter import pprint

# %%
urbana_current_url = f'{baseurl}realtime?location=61801&apikey={API_KEY_TOMORROW}'

response = requests.get(urbana_current_url)
urbana_current_data = response.json()
pprint(urbana_current_data)
# Out:
# {
#     'data': {
#         'time': '2025-06-11T18:45:00Z',
#         'values': {
#             'cloudBase': 16,
#             'cloudCeiling': 16,
#             'cloudCover': 61,
#             'dewPoint': 14.9,
#             'freezingRainIntensity': 0,
#             'humidity': 41,
#             'precipitationProbability': 0,
#             'pressureSeaLevel': 1016.66,
#             'pressureSurfaceLevel': 991.29,
#             'rainIntensity': 0,
#             'sleetIntensity': 0,
#             'snowIntensity': 0,
#             'temperature': 29.6,
#             'temperatureApparent': 29.4,
#             'uvHealthConcern': 3,
#             'uvIndex': 7,
#             'visibility': 16,
#             'weatherCode': 1101,
#             'windDirection': 208,
#             'windGust': 4.7,
#             'windSpeed': 4.1
#         }
#     },
#     'location': {
#         'lat': 40.11079406738281,
#         'lon': -88.21407318115234,
#         'name': 'Urbana, Champaign County, Illinois, 61801, United States',
#         'type': 'postcode'
#     }
# }

# %% [markdown]
# #### Question 4: Country this location is in

# %% [markdown]
# The country isn't its own dictionary, only part of a dictionary containing the entire name
#
# Workaround - reverse geocoding?

# %%
f'{urbana_current_data['location']['name']}'
# Out:
# 'Urbana, Champaign County, Illinois, 61801, United States'

# %% [markdown]
# #### Question 5: Difference between current temp and feels like temp

# %%
abs(urbana_current_data['data']['values']['temperature'] - urbana_current_data['data']['values']['temperatureApparent'])
# Out:
# 0.20000000000000284

# %% [markdown]
# #### Question 6: Current temp at Heathrow

# %%
heathrow_current_url = f'{baseurl}realtime?location=51.4680%2C%20-0.4551&apikey={API_KEY_TOMORROW}'

response = requests.get(heathrow_current_url)
heathrow_current_data = response.json()
pprint(heathrow_current_data)
# Out:
# {
#     'data': {
#         'time': '2025-06-11T18:45:00Z',
#         'values': {
#             'cloudBase': 10.4,
#             'cloudCeiling': 11.3,
#             'cloudCover': 88,
#             'dewPoint': 11.5,
#             'freezingRainIntensity': 0,
#             'humidity': 57,
#             'precipitationProbability': 0,
#             'pressureSeaLevel': 1017.04,
#             'pressureSurfaceLevel': 1014.5,
#             'rainIntensity': 0,
#             'sleetIntensity': 0,
#             'snowIntensity': 0,
#             'temperature': 20.2,
#             'temperatureApparent': 20.2,
#             'uvHealthConcern': 0,
#             'uvIndex': 0,
#             'visibility': 16,
#             'weatherCode': 1001,
#             'windDirection': 94,
#             'windGust': 8.8,
#             'windSpeed': 4.1
#         }
#     },
#     'location': {'lat': 51.468, 'lon': -0.4551}
# }

# %%
heathrow_current_data['data']['values']['temperature']
# Out:
# 20.2

# %% [markdown]
# #### Question 7: URL for 3-day forecast at Heathrow
#
# You'd use this URL, but I think the API can only give a 5-day forecast: https://api.tomorrow.io/v4/weather/forecast?location=51.4680%2C%200.4551&timesteps=1d&apikey={API_KEY_TOMORROW}
#
# Since this gives a list of dictionaries, each for a day, we can pull the first 3 elements in the list (which are dictionaries of days) or remove the last three elements (because the length of the list is 6, I guess it's inclusive of start and end day)

# %%
heathrow_5day_url = f'{baseurl}forecast?location=51.4680%2C%20-0.4551&timesteps=1d&apikey={API_KEY_TOMORROW}'

response = requests.get(heathrow_5day_url)
heathrow_5day_data = response.json()
pprint(heathrow_5day_data)
# Out:
# {
#     'timelines': {
#         'daily': [
#             {
#                 'time': '2025-06-11T05:00:00Z',
#                 'values': {
#                     'cloudBaseAvg': 3.9,
#                     'cloudBaseMax': 11.5,
#                     'cloudBaseMin': 0,
#                     'cloudCeilingAvg': 4.7,
#                     'cloudCeilingMax': 11.9,
#                     'cloudCeilingMin': 0,
#                     'cloudCoverAvg': 78,
#                     'cloudCoverMax': 100,
#                     'cloudCoverMin': 0,
#                     'dewPointAvg': 12.4,
#                     'dewPointMax': 16.3,
#                     'dewPointMin': 8.8,
#                     'evapotranspirationAvg': 0.182,
#                     'evapotranspirationMax': 0.371,
#                     'evapotranspirationMin': 0.011,
#                     'evapotranspirationSum': 4.361,
#                     'freezingRainIntensityAvg': 0,
#                     'freezingRainIntensityMax': 0,
#                     'freezingRainIntensityMin': 0,
#                     'humidityAvg': 72,
#                     'humidityMax': 91,
#                     'humidityMin': 48,
#                     'iceAccumulationAvg': 0,
#                     'iceAccumulationLweAvg': 0,
#                     'iceAccumulationLweMax': 0,
#                     'iceAccumulationLweMin': 0,
#                     'iceAccumulationLweSum': 0,
#                     'iceAccumulationMax': 0,
#                     'iceAccumulationMin': 0,
#                     'iceAccumulationSum': 0,
#                     'moonriseTime': '2025-06-11T21:15:28Z',
#                     'moonsetTime': '2025-06-11T03:04:19Z',
#                     'precipitationProbabilityAvg': 0,
#                     'precipitationProbabilityMax': 0,
#                     'precipitationProbabilityMin': 0,
#                     'pressureSeaLevelAvg': 1018.03,
#                     'pressureSeaLevelMax': 1020.65,
#                     'pressureSeaLevelMin': 1013.96,
#                     'pressureSurfaceLevelAvg': 1015.93,
#                     'pressureSurfaceLevelMax': 1021.61,
#                     'pressureSurfaceLevelMin': 1011.46,
#                     'rainAccumulationAvg': 0,
#                     'rainAccumulationMax': 0,
#                     'rainAccumulationMin': 0,
#                     'rainAccumulationSum': 0,
#                     'rainIntensityAvg': 0,
#                     'rainIntensityMax': 0,
#                     'rainIntensityMin': 0,
#                     'sleetAccumulationAvg': 0,
#                     'sleetAccumulationLweAvg': 0,
#                     'sleetAccumulationLweMax': 0,
#                     'sleetAccumulationLweMin': 0,
#                     'sleetAccumulationLweSum': 0,
#                     'sleetAccumulationMax': 0,
#                     'sleetAccumulationMin': 0,
#                     'sleetIntensityAvg': 0,
#                     'sleetIntensityMax': 0,
#                     'sleetIntensityMin': 0,
#                     'snowAccumulationAvg': 0,
#                     'snowAccumulationLweAvg': 0,
#                     'snowAccumulationLweMax': 0,
#                     'snowAccumulationLweMin': 0,
#                     'snowAccumulationLweSum': 0,
#                     'snowAccumulationMax': 0,
#                     'snowAccumulationMin': 0,
#                     'snowAccumulationSum': 0,
#                     'snowIntensityAvg': 0,
#                     'snowIntensityMax': 0,
#                     'snowIntensityMin': 0,
#                     'sunriseTime': '2025-06-11T04:08:00Z',
#                     'sunsetTime': '2025-06-11T19:54:00Z',
#                     'temperatureApparentAvg': 17.7,
#                     'temperatureApparentMax': 24.5,
#                     'temperatureApparentMin': 13.2,
#                     'temperatureAvg': 17.7,
#                     'temperatureMax': 24.5,
#                     'temperatureMin': 13.2,
#                     'uvHealthConcernAvg': 0,
#                     'uvHealthConcernMax': 2,
#                     'uvHealthConcernMin': 0,
#                     'uvIndexAvg': 2,
#                     'uvIndexMax': 5,
#                     'uvIndexMin': 0,
#                     'visibilityAvg': 16,
#                     'visibilityMax': 16,
#                     'visibilityMin': 16,
#                     'weatherCodeMax': 1001,
#                     'weatherCodeMin': 1001,
#                     'windDirectionAvg': 108,
#                     'windGustAvg': 5.3,
#                     'windGustMax': 8.9,
#                     'windGustMin': 0.4,
#                     'windSpeedAvg': 2.3,
#                     'windSpeedMax': 4.1,
#                     'windSpeedMin': 0.2
#                 }
#             },
#             {
#                 'time': '2025-06-12T05:00:00Z',
#                 'values': {
#                     'cloudBaseAvg': 2,
#                     'cloudBaseMax': 7.8,
#                     'cloudBaseMin': 0,
#                     'cloudCeilingAvg': 3.9,
#                     'cloudCeilingMax': 10.9,
#                     'cloudCeilingMin': 0,
#                     'cloudCoverAvg': 56,
#                     'cloudCoverMax': 100,
#                     'cloudCoverMin': 1,
#                     'dewPointAvg': 13.6,
#                     'dewPointMax': 15.8,
#                     'dewPointMin': 11.4,
#                     'evapotranspirationAvg': 0.157,
#                     'evapotranspirationMax': 0.276,
#                     'evapotranspirationMin': 0.076,
#                     'evapotranspirationSum': 3.765,
#                     'freezingRainIntensityAvg': 0,
#                     'freezingRainIntensityMax': 0,
#                     'freezingRainIntensityMin': 0,
#                     'humidityAvg': 71,
#                     'humidityMax': 93,
#                     'humidityMin': 49,
#                     'iceAccumulationAvg': 0,
#                     'iceAccumulationLweAvg': 0,
#                     'iceAccumulationLweMax': 0,
#                     'iceAccumulationLweMin': 0,
#                     'iceAccumulationLweSum': 0,
#                     'iceAccumulationMax': 0,
#                     'iceAccumulationMin': 0,
#                     'iceAccumulationSum': 0,
#                     'moonriseTime': '2025-06-12T22:03:45Z',
#                     'moonsetTime': '2025-06-12T03:52:43Z',
#                     'precipitationProbabilityAvg': 0.8,
#                     'precipitationProbabilityMax': 20,
#                     'precipitationProbabilityMin': 0,
#                     'pressureSeaLevelAvg': 1013.3,
#                     'pressureSeaLevelMax': 1017.3,
#                     'pressureSeaLevelMin': 1009.83,
#                     'pressureSurfaceLevelAvg': 1010.8,
#                     'pressureSurfaceLevelMax': 1014.72,
#                     'pressureSurfaceLevelMin': 1007.39,
#                     'rainAccumulationAvg': 0,
#                     'rainAccumulationMax': 0,
#                     'rainAccumulationMin': 0,
#                     'rainAccumulationSum': 0,
#                     'rainIntensityAvg': 0,
#                     'rainIntensityMax': 0.11,
#                     'rainIntensityMin': 0,
#                     'sleetIntensityAvg': 0,
#                     'sleetIntensityMax': 0,
#                     'sleetIntensityMin': 0,
#                     'snowAccumulationAvg': 0,
#                     'snowAccumulationLweAvg': 0,
#                     'snowAccumulationLweMax': 0,
#                     'snowAccumulationLweMin': 0,
#                     'snowAccumulationLweSum': 0,
#                     'snowAccumulationMax': 0,
#                     'snowAccumulationMin': 0,
#                     'snowAccumulationSum': 0,
#                     'snowIntensityAvg': 0,
#                     'snowIntensityMax': 0,
#                     'snowIntensityMin': 0,
#                     'sunriseTime': '2025-06-12T04:08:00Z',
#                     'sunsetTime': '2025-06-12T19:55:00Z',
#                     'temperatureApparentAvg': 19.3,
#                     'temperatureApparentMax': 24.8,
#                     'temperatureApparentMin': 14.6,
#                     'temperatureAvg': 19.3,
#                     'temperatureMax': 24.8,
#                     'temperatureMin': 14.6,
#                     'uvHealthConcernAvg': 0,
#                     'uvHealthConcernMax': 1,
#                     'uvHealthConcernMin': 0,
#                     'uvIndexAvg': 1,
#                     'uvIndexMax': 5,
#                     'uvIndexMin': 0,
#                     'visibilityAvg': 16,
#                     'visibilityMax': 16,
#                     'visibilityMin': 16,
#                     'weatherCodeMax': 1001,
#                     'weatherCodeMin': 1001,
#                     'windDirectionAvg': 153,
#                     'windGustAvg': 7.7,
#                     'windGustMax': 14.4,
#                     'windGustMin': 3.1,
#                     'windSpeedAvg': 3.5,
#                     'windSpeedMax': 6.5,
#                     'windSpeedMin': 1.7
#                 }
#             },
#             {
#                 'time': '2025-06-13T05:00:00Z',
#                 'values': {
#                     'cloudBaseAvg': 1.6,
#                     'cloudBaseMax': 9.3,
#                     'cloudBaseMin': 0,
#                     'cloudCeilingAvg': 1.9,
#                     'cloudCeilingMax': 10.4,
#                     'cloudCeilingMin': 0,
#                     'cloudCoverAvg': 59,
#                     'cloudCoverMax': 100,
#                     'cloudCoverMin': 2,
#                     'dewPointAvg': 14.1,
#                     'dewPointMax': 16.2,
#                     'dewPointMin': 12.1,
#                     'evapotranspirationAvg': 0.163,
#                     'evapotranspirationMax': 0.239,
#                     'evapotranspirationMin': 0.09,
#                     'evapotranspirationSum': 3.909,
#                     'freezingRainIntensityAvg': 0,
#                     'freezingRainIntensityMax': 0,
#                     'freezingRainIntensityMin': 0,
#                     'humidityAvg': 67,
#                     'humidityMax': 94,
#                     'humidityMin': 42,
#                     'iceAccumulationAvg': 0,
#                     'iceAccumulationLweAvg': 0,
#                     'iceAccumulationLweMax': 0,
#                     'iceAccumulationLweMin': 0,
#                     'iceAccumulationLweSum': 0,
#                     'iceAccumulationMax': 0,
#                     'iceAccumulationMin': 0,
#                     'iceAccumulationSum': 0,
#                     'moonriseTime': '2025-06-13T22:40:41Z',
#                     'moonsetTime': '2025-06-13T04:56:57Z',
#                     'precipitationProbabilityAvg': 3.8,
#                     'precipitationProbabilityMax': 20,
#                     'precipitationProbabilityMin': 0,
#                     'pressureSeaLevelAvg': 1017.55,
#                     'pressureSeaLevelMax': 1019.09,
#                     'pressureSeaLevelMin': 1014.96,
#                     'pressureSurfaceLevelAvg': 1015.05,
#                     'pressureSurfaceLevelMax': 1016.54,
#                     'pressureSurfaceLevelMin': 1012.41,
#                     'rainAccumulationAvg': 0.08,
#                     'rainAccumulationMax': 1.54,
#                     'rainAccumulationMin': 0,
#                     'rainAccumulationSum': 1.88,
#                     'rainIntensityAvg': 0.11,
#                     'rainIntensityMax': 1.2,
#                     'rainIntensityMin': 0,
#                     'sleetIntensityAvg': 0,
#                     'sleetIntensityMax': 0,
#                     'sleetIntensityMin': 0,
#                     'snowAccumulationAvg': 0,
#                     'snowAccumulationLweAvg': 0,
#                     'snowAccumulationLweMax': 0,
#                     'snowAccumulationLweMin': 0,
#                     'snowAccumulationLweSum': 0,
#                     'snowAccumulationMax': 0,
#                     'snowAccumulationMin': 0,
#                     'snowAccumulationSum': 0,
#                     'snowIntensityAvg': 0,
#                     'snowIntensityMax': 0,
#                     'snowIntensityMin': 0,
#                     'sunriseTime': '2025-06-13T04:08:00Z',
#                     'sunsetTime': '2025-06-13T19:55:00Z',
#                     'temperatureApparentAvg': 21.3,
#                     'temperatureApparentMax': 26.6,
#                     'temperatureApparentMin': 15.3,
#                     'temperatureAvg': 21.3,
#                     'temperatureMax': 26.6,
#                     'temperatureMin': 15.3,
#                     'uvHealthConcernAvg': 0,
#                     'uvHealthConcernMax': 1,
#                     'uvHealthConcernMin': 0,
#                     'uvIndexAvg': 1,
#                     'uvIndexMax': 3,
#                     'uvIndexMin': 0,
#                     'visibilityAvg': 14.94,
#                     'visibilityMax': 16,
#                     'visibilityMin': 6.47,
#                     'weatherCodeMax': 1001,
#                     'weatherCodeMin': 1001,
#                     'windDirectionAvg': 161,
#                     'windGustAvg': 5.2,
#                     'windGustMax': 8.6,
#                     'windGustMin': 0.3,
#                     'windSpeedAvg': 2.2,
#                     'windSpeedMax': 3.6,
#                     'windSpeedMin': 0.1
#                 }
#             },
#             {
#                 'time': '2025-06-14T05:00:00Z',
#                 'values': {
#                     'cloudBaseAvg': 1,
#                     'cloudBaseMax': 3.9,
#                     'cloudBaseMin': 0,
#                     'cloudCeilingAvg': 1.4,
#                     'cloudCeilingMax': 9.8,
#                     'cloudCeilingMin': 0,
#                     'cloudCoverAvg': 40,
#                     'cloudCoverMax': 100,
#                     'cloudCoverMin': 0,
#                     'dewPointAvg': 12.6,
#                     'dewPointMax': 16.6,
#                     'dewPointMin': 9.1,
#                     'evapotranspirationAvg': 0.168,
#                     'evapotranspirationMax': 0.266,
#                     'evapotranspirationMin': 0.097,
#                     'evapotranspirationSum': 4.04,
#                     'freezingRainIntensityAvg': 0,
#                     'freezingRainIntensityMax': 0,
#                     'freezingRainIntensityMin': 0,
#                     'humidityAvg': 69,
#                     'humidityMax': 91,
#                     'humidityMin': 42,
#                     'iceAccumulationAvg': 0,
#                     'iceAccumulationLweAvg': 0,
#                     'iceAccumulationLweMax': 0,
#                     'iceAccumulationLweMin': 0,
#                     'iceAccumulationLweSum': 0,
#                     'iceAccumulationMax': 0,
#                     'iceAccumulationMin': 0,
#                     'iceAccumulationSum': 0,
#                     'moonriseTime': '2025-06-14T23:06:06Z',
#                     'moonsetTime': '2025-06-14T06:11:55Z',
#                     'precipitationProbabilityAvg': 0.6,
#                     'precipitationProbabilityMax': 10,
#                     'precipitationProbabilityMin': 0,
#                     'pressureSeaLevelAvg': 1017.47,
#                     'pressureSeaLevelMax': 1020.99,
#                     'pressureSeaLevelMin': 1015.15,
#                     'pressureSurfaceLevelAvg': 1014.97,
#                     'pressureSurfaceLevelMax': 1018.51,
#                     'pressureSurfaceLevelMin': 1012.71,
#                     'rainAccumulationAvg': 0,
#                     'rainAccumulationMax': 0,
#                     'rainAccumulationMin': 0,
#                     'rainAccumulationSum': 0,
#                     'rainIntensityAvg': 0.01,
#                     'rainIntensityMax': 0.13,
#                     'rainIntensityMin': 0,
#                     'sleetIntensityAvg': 0,
#                     'sleetIntensityMax': 0,
#                     'sleetIntensityMin': 0,
#                     'snowAccumulationAvg': 0,
#                     'snowAccumulationLweAvg': 0,
#                     'snowAccumulationLweMax': 0,
#                     'snowAccumulationLweMin': 0,
#                     'snowAccumulationLweSum': 0,
#                     'snowAccumulationMax': 0,
#                     'snowAccumulationMin': 0,
#                     'snowAccumulationSum': 0,
#                     'snowIntensityAvg': 0,
#                     'snowIntensityMax': 0,
#                     'snowIntensityMin': 0,
#                     'sunriseTime': '2025-06-14T04:08:00Z',
#                     'sunsetTime': '2025-06-14T19:56:00Z',
#                     'temperatureApparentAvg': 19.1,
#                     'temperatureApparentMax': 23.8,
#                     'temperatureApparentMin': 13.3,
#                     'temperatureAvg': 19.1,
#                     'temperatureMax': 23.8,
#                     'temperatureMin': 13.3,
#                     'uvHealthConcernAvg': 0,
#                     'uvHealthConcernMax': 2,
#                     'uvHealthConcernMin': 0,
#                     'uvIndexAvg': 2,
#                     'uvIndexMax': 6,
#                     'uvIndexMin': 0,
#                     'visibilityAvg': 15.86,
#                     'visibilityMax': 16,
#                     'visibilityMin': 12.61,
#                     'weatherCodeMax': 1100,
#                     'weatherCodeMin': 1100,
#                     'windDirectionAvg': 224,
#                     'windGustAvg': 8.4,
#                     'windGustMax': 13.1,
#                     'windGustMin': 1.8,
#                     'windSpeedAvg': 3.7,
#                     'windSpeedMax': 5.7,
#                     'windSpeedMin': 0.9
#                 }
#             },
#             {
#                 'time': '2025-06-15T05:00:00Z',
#                 'values': {
#                     'cloudBaseAvg': 1,
#                     'cloudBaseMax': 2,
#                     'cloudBaseMin': 0,
#                     'cloudCeilingAvg': 0.4,
#                     'cloudCeilingMax': 1.3,
#                     'cloudCeilingMin': 0,
#                     'cloudCoverAvg': 46,
#                     'cloudCoverMax': 100,
#                     'cloudCoverMin': 0,
#                     'dewPointAvg': 10.8,
#                     'dewPointMax': 12.4,
#                     'dewPointMin': 8.8,
#                     'evapotranspirationAvg': 0.15,
#                     'evapotranspirationMax': 0.223,
#                     'evapotranspirationMin': 0.098,
#                     'evapotranspirationSum': 3.596,
#                     'freezingRainIntensityAvg': 0,
#                     'freezingRainIntensityMax': 0,
#                     'freezingRainIntensityMin': 0,
#                     'humidityAvg': 64,
#                     'humidityMax': 86,
#                     'humidityMin': 42,
#                     'iceAccumulationAvg': 0,
#                     'iceAccumulationLweAvg': 0,
#                     'iceAccumulationLweMax': 0,
#                     'iceAccumulationLweMin': 0,
#                     'iceAccumulationLweSum': 0,
#                     'iceAccumulationMax': 0,
#                     'iceAccumulationMin': 0,
#                     'iceAccumulationSum': 0,
#                     'moonriseTime': '2025-06-15T23:26:26Z',
#                     'moonsetTime': '2025-06-15T07:34:13Z',
#                     'precipitationProbabilityAvg': 1.9,
#                     'precipitationProbabilityMax': 5,
#                     'precipitationProbabilityMin': 0,
#                     'pressureSeaLevelAvg': 1023.69,
#                     'pressureSeaLevelMax': 1026.3,
#                     'pressureSeaLevelMin': 1020.85,
#                     'pressureSurfaceLevelAvg': 1021.17,
#                     'pressureSurfaceLevelMax': 1023.68,
#                     'pressureSurfaceLevelMin': 1018.4,
#                     'rainAccumulationAvg': 0,
#                     'rainAccumulationMax': 0,
#                     'rainAccumulationMin': 0,
#                     'rainAccumulationSum': 0,
#                     'rainIntensityAvg': 0.04,
#                     'rainIntensityMax': 0.18,
#                     'rainIntensityMin': 0,
#                     'sleetIntensityAvg': 0,
#                     'sleetIntensityMax': 0,
#                     'sleetIntensityMin': 0,
#                     'snowAccumulationAvg': 0,
#                     'snowAccumulationLweAvg': 0,
#                     'snowAccumulationLweMax': 0,
#                     'snowAccumulationLweMin': 0,
#                     'snowAccumulationLweSum': 0,
#                     'snowAccumulationMax': 0,
#                     'snowAccumulationMin': 0,
#                     'snowAccumulationSum': 0,
#                     'snowIntensityAvg': 0,
#                     'snowIntensityMax': 0,
#                     'snowIntensityMin': 0,
#                     'sunriseTime': '2025-06-15T04:08:00Z',
#                     'sunsetTime': '2025-06-15T19:56:00Z',
#                     'temperatureApparentAvg': 18.2,
#                     'temperatureApparentMax': 22.4,
#                     'temperatureApparentMin': 13.5,
#                     'temperatureAvg': 18.2,
#                     'temperatureMax': 22.4,
#                     'temperatureMin': 13.5,
#                     'uvHealthConcernAvg': 0,
#                     'uvHealthConcernMax': 1,
#                     'uvHealthConcernMin': 0,
#                     'uvIndexAvg': 1,
#                     'uvIndexMax': 5,
#                     'uvIndexMin': 0,
#                     'visibilityAvg': 16,
#                     'visibilityMax': 16,
#                     'visibilityMin': 16,
#                     'weatherCodeMax': 1001,
#                     'weatherCodeMin': 1001,
#                     'windDirectionAvg': 294,
#                     'windGustAvg': 6.4,
#                     'windGustMax': 10.4,
#                     'windGustMin': 3.4,
#                     'windSpeedAvg': 2.8,
#                     'windSpeedMax': 4.4,
#                     'windSpeedMin': 1.8
#                 }
#             },
#             {
#                 'time': '2025-06-16T05:00:00Z',
#                 'values': {
#                     'cloudBaseAvg': 0.9,
#                     'cloudBaseMax': 1.7,
#                     'cloudBaseMin': 0,
#                     'cloudCeilingAvg': 0.2,
#                     'cloudCeilingMax': 1.2,
#                     'cloudCeilingMin': 0,
#                     'cloudCoverAvg': 22,
#                     'cloudCoverMax': 56,
#                     'cloudCoverMin': 0,
#                     'dewPointAvg': 10.7,
#                     'dewPointMax': 12.3,
#                     'dewPointMin': 8.7,
#                     'evapotranspirationAvg': 0.135,
#                     'evapotranspirationMax': 0.208,
#                     'evapotranspirationMin': 0.105,
#                     'evapotranspirationSum': 3.249,
#                     'freezingRainIntensityAvg': 0,
#                     'freezingRainIntensityMax': 0,
#                     'freezingRainIntensityMin': 0,
#                     'humidityAvg': 59,
#                     'humidityMax': 84,
#                     'humidityMin': 39,
#                     'iceAccumulationAvg': 0,
#                     'iceAccumulationLweAvg': 0,
#                     'iceAccumulationLweMax': 0,
#                     'iceAccumulationLweMin': 0,
#                     'iceAccumulationLweSum': 0,
#                     'iceAccumulationMax': 0,
#                     'iceAccumulationMin': 0,
#                     'iceAccumulationSum': 0,
#                     'moonriseTime': '2025-06-16T23:42:23Z',
#                     'moonsetTime': '2025-06-16T08:59:43Z',
#                     'precipitationProbabilityAvg': 0,
#                     'precipitationProbabilityMax': 0,
#                     'precipitationProbabilityMin': 0,
#                     'pressureSeaLevelAvg': 1026.76,
#                     'pressureSeaLevelMax': 1028.99,
#                     'pressureSeaLevelMin': 1024.85,
#                     'pressureSurfaceLevelAvg': 1024.25,
#                     'pressureSurfaceLevelMax': 1026.46,
#                     'pressureSurfaceLevelMin': 1022.26,
#                     'rainAccumulationAvg': 0,
#                     'rainAccumulationMax': 0,
#                     'rainAccumulationMin': 0,
#                     'rainAccumulationSum': 0,
#                     'rainIntensityAvg': 0,
#                     'rainIntensityMax': 0,
#                     'rainIntensityMin': 0,
#                     'sleetIntensityAvg': 0,
#                     'sleetIntensityMax': 0,
#                     'sleetIntensityMin': 0,
#                     'snowAccumulationAvg': 0,
#                     'snowAccumulationLweAvg': 0,
#                     'snowAccumulationLweMax': 0,
#                     'snowAccumulationLweMin': 0,
#                     'snowAccumulationLweSum': 0,
#                     'snowAccumulationMax': 0,
#                     'snowAccumulationMin': 0,
#                     'snowAccumulationSum': 0,
#                     'snowIntensityAvg': 0,
#                     'snowIntensityMax': 0,
#                     'snowIntensityMin': 0,
#                     'sunriseTime': '2025-06-16T04:08:00Z',
#                     'sunsetTime': '2025-06-16T19:56:00Z',
#                     'temperatureApparentAvg': 19.6,
#                     'temperatureApparentMax': 24.2,
#                     'temperatureApparentMin': 14.8,
#                     'temperatureAvg': 19.6,
#                     'temperatureMax': 24.2,
#                     'temperatureMin': 14.8,
#                     'visibilityAvg': 16,
#                     'visibilityMax': 16,
#                     'visibilityMin': 16,
#                     'weatherCodeMax': 1100,
#                     'weatherCodeMin': 1000,
#                     'windDirectionAvg': 203,
#                     'windGustAvg': 4,
#                     'windGustMax': 6.4,
#                     'windGustMin': 0.7,
#                     'windSpeedAvg': 1.3,
#                     'windSpeedMax': 2.6,
#                     'windSpeedMin': 0.3
#                 }
#             }
#         ]
#     },
#     'location': {'lat': 51.468, 'lon': -0.4551}
# }

# %%
# the list we need to remove the last few elements in:
len(heathrow_5day_data['timelines']['daily'])
# answer = 6, so we need to remove the last 3 - we can just remove last item three times

heathrow_5day_data['timelines']['daily'].pop()
heathrow_5day_data['timelines']['daily'].pop()
heathrow_5day_data['timelines']['daily'].pop()

heathrow_3day_data = heathrow_5day_data['timelines']['daily']
heathrow_3day_data
# Out:
# [{'time': '2025-06-11T05:00:00Z',
#   'values': {'cloudBaseAvg': 3.9,
#    'cloudBaseMax': 11.5,
#    'cloudBaseMin': 0,
#    'cloudCeilingAvg': 4.7,
#    'cloudCeilingMax': 11.9,
#    'cloudCeilingMin': 0,
#    'cloudCoverAvg': 78,
#    'cloudCoverMax': 100,
#    'cloudCoverMin': 0,
#    'dewPointAvg': 12.4,
#    'dewPointMax': 16.3,
#    'dewPointMin': 8.8,
#    'evapotranspirationAvg': 0.182,
#    'evapotranspirationMax': 0.371,
#    'evapotranspirationMin': 0.011,
#    'evapotranspirationSum': 4.361,
#    'freezingRainIntensityAvg': 0,
#    'freezingRainIntensityMax': 0,
#    'freezingRainIntensityMin': 0,
#    'humidityAvg': 72,
#    'humidityMax': 91,
#    'humidityMin': 48,
#    'iceAccumulationAvg': 0,
#    'iceAccumulationLweAvg': 0,
#    'iceAccumulationLweMax': 0,
#    'iceAccumulationLweMin': 0,
#    'iceAccumulationLweSum': 0,
#    'iceAccumulationMax': 0,
#    'iceAccumulationMin': 0,
#    'iceAccumulationSum': 0,
#    'moonriseTime': '2025-06-11T21:15:28Z',
#    'moonsetTime': '2025-06-11T03:04:19Z',
#    'precipitationProbabilityAvg': 0,
#    'precipitationProbabilityMax': 0,
#    'precipitationProbabilityMin': 0,
#    'pressureSeaLevelAvg': 1018.03,
#    'pressureSeaLevelMax': 1020.65,
#    'pressureSeaLevelMin': 1013.96,
#    'pressureSurfaceLevelAvg': 1015.93,
#    'pressureSurfaceLevelMax': 1021.61,
#    'pressureSurfaceLevelMin': 1011.46,
#    'rainAccumulationAvg': 0,
#    'rainAccumulationMax': 0,
#    'rainAccumulationMin': 0,
#    'rainAccumulationSum': 0,
#    'rainIntensityAvg': 0,
#    'rainIntensityMax': 0,
#    'rainIntensityMin': 0,
#    'sleetAccumulationAvg': 0,
#    'sleetAccumulationLweAvg': 0,
#    'sleetAccumulationLweMax': 0,
#    'sleetAccumulationLweMin': 0,
#    'sleetAccumulationLweSum': 0,
#    'sleetAccumulationMax': 0,
#    'sleetAccumulationMin': 0,
#    'sleetIntensityAvg': 0,
#    'sleetIntensityMax': 0,
#    'sleetIntensityMin': 0,
#    'snowAccumulationAvg': 0,
#    'snowAccumulationLweAvg': 0,
#    'snowAccumulationLweMax': 0,
#    'snowAccumulationLweMin': 0,
#    'snowAccumulationLweSum': 0,
#    'snowAccumulationMax': 0,
#    'snowAccumulationMin': 0,
#    'snowAccumulationSum': 0,
#    'snowIntensityAvg': 0,
#    'snowIntensityMax': 0,
#    'snowIntensityMin': 0,
#    'sunriseTime': '2025-06-11T04:08:00Z',
#    'sunsetTime': '2025-06-11T19:54:00Z',
#    'temperatureApparentAvg': 17.7,
#    'temperatureApparentMax': 24.5,
#    'temperatureApparentMin': 13.2,
#    'temperatureAvg': 17.7,
#    'temperatureMax': 24.5,
#    'temperatureMin': 13.2,
#    'uvHealthConcernAvg': 0,
#    'uvHealthConcernMax': 2,
#    'uvHealthConcernMin': 0,
#    'uvIndexAvg': 2,
#    'uvIndexMax': 5,
#    'uvIndexMin': 0,
#    'visibilityAvg': 16,
#    'visibilityMax': 16,
#    'visibilityMin': 16,
#    'weatherCodeMax': 1001,
#    'weatherCodeMin': 1001,
#    'windDirectionAvg': 108,
#    'windGustAvg': 5.3,
#    'windGustMax': 8.9,
#    'windGustMin': 0.4,
#    'windSpeedAvg': 2.3,
#    'windSpeedMax': 4.1,
#    'windSpeedMin': 0.2}},
#  {'time': '2025-06-12T05:00:00Z',
#   'values': {'cloudBaseAvg': 2,
#    'cloudBaseMax': 7.8,
#    'cloudBaseMin': 0,
#    'cloudCeilingAvg': 3.9,
#    'cloudCeilingMax': 10.9,
#    'cloudCeilingMin': 0,
#    'cloudCoverAvg': 56,
#    'cloudCoverMax': 100,
#    'cloudCoverMin': 1,
#    'dewPointAvg': 13.6,
#    'dewPointMax': 15.8,
#    'dewPointMin': 11.4,
#    'evapotranspirationAvg': 0.157,
#    'evapotranspirationMax': 0.276,
#    'evapotranspirationMin': 0.076,
#    'evapotranspirationSum': 3.765,
#    'freezingRainIntensityAvg': 0,
#    'freezingRainIntensityMax': 0,
#    'freezingRainIntensityMin': 0,
#    'humidityAvg': 71,
#    'humidityMax': 93,
#    'humidityMin': 49,
#    'iceAccumulationAvg': 0,
#    'iceAccumulationLweAvg': 0,
#    'iceAccumulationLweMax': 0,
#    'iceAccumulationLweMin': 0,
#    'iceAccumulationLweSum': 0,
#    'iceAccumulationMax': 0,
#    'iceAccumulationMin': 0,
#    'iceAccumulationSum': 0,
#    'moonriseTime': '2025-06-12T22:03:45Z',
#    'moonsetTime': '2025-06-12T03:52:43Z',
#    'precipitationProbabilityAvg': 0.8,
#    'precipitationProbabilityMax': 20,
#    'precipitationProbabilityMin': 0,
#    'pressureSeaLevelAvg': 1013.3,
#    'pressureSeaLevelMax': 1017.3,
#    'pressureSeaLevelMin': 1009.83,
#    'pressureSurfaceLevelAvg': 1010.8,
#    'pressureSurfaceLevelMax': 1014.72,
#    'pressureSurfaceLevelMin': 1007.39,
#    'rainAccumulationAvg': 0,
#    'rainAccumulationMax': 0,
#    'rainAccumulationMin': 0,
#    'rainAccumulationSum': 0,
#    'rainIntensityAvg': 0,
#    'rainIntensityMax': 0.11,
#    'rainIntensityMin': 0,
#    'sleetIntensityAvg': 0,
#    'sleetIntensityMax': 0,
#    'sleetIntensityMin': 0,
#    'snowAccumulationAvg': 0,
#    'snowAccumulationLweAvg': 0,
#    'snowAccumulationLweMax': 0,
#    'snowAccumulationLweMin': 0,
#    'snowAccumulationLweSum': 0,
#    'snowAccumulationMax': 0,
#    'snowAccumulationMin': 0,
#    'snowAccumulationSum': 0,
#    'snowIntensityAvg': 0,
#    'snowIntensityMax': 0,
#    'snowIntensityMin': 0,
#    'sunriseTime': '2025-06-12T04:08:00Z',
#    'sunsetTime': '2025-06-12T19:55:00Z',
#    'temperatureApparentAvg': 19.3,
#    'temperatureApparentMax': 24.8,
#    'temperatureApparentMin': 14.6,
#    'temperatureAvg': 19.3,
#    'temperatureMax': 24.8,
#    'temperatureMin': 14.6,
#    'uvHealthConcernAvg': 0,
#    'uvHealthConcernMax': 1,
#    'uvHealthConcernMin': 0,
#    'uvIndexAvg': 1,
#    'uvIndexMax': 5,
#    'uvIndexMin': 0,
#    'visibilityAvg': 16,
#    'visibilityMax': 16,
#    'visibilityMin': 16,
#    'weatherCodeMax': 1001,
#    'weatherCodeMin': 1001,
#    'windDirectionAvg': 153,
#    'windGustAvg': 7.7,
#    'windGustMax': 14.4,
#    'windGustMin': 3.1,
#    'windSpeedAvg': 3.5,
#    'windSpeedMax': 6.5,
#    'windSpeedMin': 1.7}},
#  {'time': '2025-06-13T05:00:00Z',
#   'values': {'cloudBaseAvg': 1.6,
#    'cloudBaseMax': 9.3,
#    'cloudBaseMin': 0,
#    'cloudCeilingAvg': 1.9,
#    'cloudCeilingMax': 10.4,
#    'cloudCeilingMin': 0,
#    'cloudCoverAvg': 59,
#    'cloudCoverMax': 100,
#    'cloudCoverMin': 2,
#    'dewPointAvg': 14.1,
#    'dewPointMax': 16.2,
#    'dewPointMin': 12.1,
#    'evapotranspirationAvg': 0.163,
#    'evapotranspirationMax': 0.239,
#    'evapotranspirationMin': 0.09,
#    'evapotranspirationSum': 3.909,
#    'freezingRainIntensityAvg': 0,
#    'freezingRainIntensityMax': 0,
#    'freezingRainIntensityMin': 0,
#    'humidityAvg': 67,
#    'humidityMax': 94,
#    'humidityMin': 42,
#    'iceAccumulationAvg': 0,
#    'iceAccumulationLweAvg': 0,
#    'iceAccumulationLweMax': 0,
#    'iceAccumulationLweMin': 0,
#    'iceAccumulationLweSum': 0,
#    'iceAccumulationMax': 0,
#    'iceAccumulationMin': 0,
#    'iceAccumulationSum': 0,
#    'moonriseTime': '2025-06-13T22:40:41Z',
#    'moonsetTime': '2025-06-13T04:56:57Z',
#    'precipitationProbabilityAvg': 3.8,
#    'precipitationProbabilityMax': 20,
#    'precipitationProbabilityMin': 0,
#    'pressureSeaLevelAvg': 1017.55,
#    'pressureSeaLevelMax': 1019.09,
#    'pressureSeaLevelMin': 1014.96,
#    'pressureSurfaceLevelAvg': 1015.05,
#    'pressureSurfaceLevelMax': 1016.54,
#    'pressureSurfaceLevelMin': 1012.41,
#    'rainAccumulationAvg': 0.08,
#    'rainAccumulationMax': 1.54,
#    'rainAccumulationMin': 0,
#    'rainAccumulationSum': 1.88,
#    'rainIntensityAvg': 0.11,
#    'rainIntensityMax': 1.2,
#    'rainIntensityMin': 0,
#    'sleetIntensityAvg': 0,
#    'sleetIntensityMax': 0,
#    'sleetIntensityMin': 0,
#    'snowAccumulationAvg': 0,
#    'snowAccumulationLweAvg': 0,
#    'snowAccumulationLweMax': 0,
#    'snowAccumulationLweMin': 0,
#    'snowAccumulationLweSum': 0,
#    'snowAccumulationMax': 0,
#    'snowAccumulationMin': 0,
#    'snowAccumulationSum': 0,
#    'snowIntensityAvg': 0,
#    'snowIntensityMax': 0,
#    'snowIntensityMin': 0,
#    'sunriseTime': '2025-06-13T04:08:00Z',
#    'sunsetTime': '2025-06-13T19:55:00Z',
#    'temperatureApparentAvg': 21.3,
#    'temperatureApparentMax': 26.6,
#    'temperatureApparentMin': 15.3,
#    'temperatureAvg': 21.3,
#    'temperatureMax': 26.6,
#    'temperatureMin': 15.3,
#    'uvHealthConcernAvg': 0,
#    'uvHealthConcernMax': 1,
#    'uvHealthConcernMin': 0,
#    'uvIndexAvg': 1,
#    'uvIndexMax': 3,
#    'uvIndexMin': 0,
#    'visibilityAvg': 14.94,
#    'visibilityMax': 16,
#    'visibilityMin': 6.47,
#    'weatherCodeMax': 1001,
#    'weatherCodeMin': 1001,
#    'windDirectionAvg': 161,
#    'windGustAvg': 5.2,
#    'windGustMax': 8.6,
#    'windGustMin': 0.3,
#    'windSpeedAvg': 2.2,
#    'windSpeedMax': 3.6,
#    'windSpeedMin': 0.1}}]

# %% [markdown]
# #### Question 8: Print the date of each of the 3 forecast days

# %%
for date in heathrow_3day_data:
    print(date['time'])
# Out:
# 2025-06-11T05:00:00Z
# 2025-06-12T05:00:00Z
# 2025-06-13T05:00:00Z

# %% [markdown]
# #### Question 9: Print max temp of each day

# %%
for date in heathrow_3day_data:
    print(f'{date['time']}: {date['values']['temperatureMax']} degrees C')
# Out:
# 2025-06-11T05:00:00Z: 24.5 degrees C
# 2025-06-12T05:00:00Z: 24.8 degrees C
# 2025-06-13T05:00:00Z: 26.6 degrees C

# %% [markdown]
# #### Question 10: Print only the day with the highest max temp

# %%
hottestday = max(heathrow_3day_data, key=lambda date:date['values']['temperatureMax'])

f"The hottest day is {hottestday['time']}"

# the max function (like the min or sorted function) takes the list of dictionaries heathrow_3day_forecast['forecast']['forecastday'] and finds the dictionary with the largest value for the key ['day']['maxtemp_f']
# hottestday = that dictionary
# but just printing 'hottestday' here would print out the whole dictionary for that hottest day, rather than the value of the hottest day
# so to print the date of the hottest day, we print the key ['date'] for the dictionary hottestday
# Out:
# 'The hottest day is 2025-06-13T05:00:00Z'
