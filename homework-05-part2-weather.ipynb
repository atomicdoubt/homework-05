# %% [markdown]
# # A WeatherAPI alternative

# %% [markdown]
# #### Question 1: Open Meteo or Tomorrow?
#
# I'm going to start with Tomorrow, since the way to request Open Meteo data seems to use a lot of new libraries that look complicated, whereas Tomorrow looks more familiar. Open Meteo also looked too fancy and it was less obvious how to get a simple url

# %% [markdown]
# #### Question 2: URL to documentation
#
# I think it's https://docs.tomorrow.io/reference/welcome, but then there are individual pages for different things you can do. The weather forecast doc is: https://docs.tomorrow.io/reference/weather-forecast

# %% [markdown]
# #### Question 3: Request for current weather in Urbana, IL

# %%
from dotenv import load_dotenv
import os

load_dotenv()

API_KEY_TOMORROW = os.getenv("API_KEY_TOMORROW")

# %%
baseurl = 'https://api.tomorrow.io/v4/weather/'

import requests
from prettyprinter import pprint

# %%
urbana_current_url = f'{baseurl}realtime?location=61801&apikey={API_KEY_TOMORROW}'

response = requests.get(urbana_current_url)
urbana_current_data = response.json()
pprint(urbana_current_data)
# Out:
# {
#     'data': {
#         'time': '2025-06-09T23:16:00Z',
#         'values': {
#             'cloudBase': 5.7,
#             'cloudCeiling': 5.7,
#             'cloudCover': 66,
#             'dewPoint': 9.2,
#             'freezingRainIntensity': 0,
#             'humidity': 41,
#             'precipitationProbability': 0,
#             'pressureSeaLevel': 1006.81,
#             'pressureSurfaceLevel': 981.06,
#             'rainIntensity': 0,
#             'sleetIntensity': 0,
#             'snowIntensity': 0,
#             'temperature': 23.3,
#             'temperatureApparent': 23.3,
#             'uvHealthConcern': 0,
#             'uvIndex': 1,
#             'visibility': 16,
#             'weatherCode': 1102,
#             'windDirection': 286,
#             'windGust': 9.4,
#             'windSpeed': 4.6
#         }
#     },
#     'location': {
#         'lat': 40.11079406738281,
#         'lon': -88.21407318115234,
#         'name': 'Urbana, Champaign County, Illinois, 61801, United States',
#         'type': 'postcode'
#     }
# }

# %% [markdown]
# #### Question 4: Country this location is in

# %% [markdown]
# The country isn't its own dictionary, only part of a dictionary containing the entire name
#
# Workaround - reverse geocoding?

# %%
f'{urbana_current_data['location']['name']}'
# Out:
# 'Urbana, Champaign County, Illinois, 61801, United States'

# %% [markdown]
# #### Question 5: Difference between current temp and feels like temp

# %%
abs(urbana_current_data['data']['values']['temperature'] - urbana_current_data['data']['values']['temperatureApparent'])
# Out:
# 0.0

# %% [markdown]
# #### Question 6: Current temp at Heathrow

# %%
heathrow_current_url = f'{baseurl}realtime?location=51.4680%2C%20-0.4551&apikey={API_KEY_TOMORROW}'

response = requests.get(heathrow_current_url)
heathrow_current_data = response.json()
pprint(heathrow_current_data)
# Out:
# {
#     'data': {
#         'time': '2025-06-09T23:16:00Z',
#         'values': {
#             'cloudBase': 1.1,
#             'cloudCeiling': 5.9,
#             'cloudCover': 100,
#             'dewPoint': 10.4,
#             'freezingRainIntensity': 0,
#             'humidity': 79,
#             'precipitationProbability': 0,
#             'pressureSeaLevel': 1018.13,
#             'pressureSurfaceLevel': 1020.37,
#             'rainIntensity': 0,
#             'sleetIntensity': 0,
#             'snowIntensity': 0,
#             'temperature': 14,
#             'temperatureApparent': 14,
#             'uvHealthConcern': 0,
#             'uvIndex': 0,
#             'visibility': 16,
#             'weatherCode': 1001,
#             'windDirection': 226,
#             'windGust': 0,
#             'windSpeed': 0
#         }
#     },
#     'location': {'lat': 51.468, 'lon': -0.4551}
# }

# %%
heathrow_current_data['data']['values']['temperature']
# Out:
# 14

# %% [markdown]
# #### Question 7: URL for 3-day forecast at Heathrow
#
# You'd use this URL, but I think the API can only give a 5-day forecast: https://api.tomorrow.io/v4/weather/forecast?location=51.4680%2C%200.4551&timesteps=1d&apikey={API_KEY_TOMORROW}
#
# Since this gives a list of dictionaries, each for a day, we can pull the first 3 elements in the list (which are dictionaries of days) or remove the last three elements (because the length of the list is 6, I guess it's inclusive of start and end day)

# %%
heathrow_5day_url = f'{baseurl}forecast?location=51.4680%2C%20-0.4551&timesteps=1d&apikey={API_KEY_TOMORROW}'

response = requests.get(heathrow_5day_url)
heathrow_5day_data = response.json()
pprint(heathrow_5day_data)
# Out:
# {
#     'timelines': {
#         'daily': [
#             {
#                 'time': '2025-06-09T05:00:00Z',
#                 'values': {
#                     'cloudBaseAvg': 1.6,
#                     'cloudBaseMax': 6.2,
#                     'cloudBaseMin': 0,
#                     'cloudCeilingAvg': 4.3,
#                     'cloudCeilingMax': 9.7,
#                     'cloudCeilingMin': 0,
#                     'cloudCoverAvg': 94,
#                     'cloudCoverMax': 100,
#                     'cloudCoverMin': 34,
#                     'dewPointAvg': 10.8,
#                     'dewPointMax': 12.3,
#                     'dewPointMin': 8.9,
#                     'evapotranspirationAvg': 0.157,
#                     'evapotranspirationMax': 0.289,
#                     'evapotranspirationMin': 0.008,
#                     'evapotranspirationSum': 3.756,
#                     'freezingRainIntensityAvg': 0,
#                     'freezingRainIntensityMax': 0,
#                     'freezingRainIntensityMin': 0,
#                     'humidityAvg': 72,
#                     'humidityMax': 88,
#                     'humidityMin': 53,
#                     'iceAccumulationAvg': 0,
#                     'iceAccumulationLweAvg': 0,
#                     'iceAccumulationLweMax': 0,
#                     'iceAccumulationLweMin': 0,
#                     'iceAccumulationLweSum': 0,
#                     'iceAccumulationMax': 0,
#                     'iceAccumulationMin': 0,
#                     'iceAccumulationSum': 0,
#                     'moonriseTime': '2025-06-09T19:04:47Z',
#                     'moonsetTime': '2025-06-09T02:05:00Z',
#                     'precipitationProbabilityAvg': 0,
#                     'precipitationProbabilityMax': 0,
#                     'precipitationProbabilityMin': 0,
#                     'pressureSeaLevelAvg': 1019.77,
#                     'pressureSeaLevelMax': 1022.11,
#                     'pressureSeaLevelMin': 1016.32,
#                     'pressureSurfaceLevelAvg': 1017.61,
#                     'pressureSurfaceLevelMax': 1024.03,
#                     'pressureSurfaceLevelMin': 1013.75,
#                     'rainAccumulationAvg': 0,
#                     'rainAccumulationMax': 0,
#                     'rainAccumulationMin': 0,
#                     'rainAccumulationSum': 0,
#                     'rainIntensityAvg': 0,
#                     'rainIntensityMax': 0,
#                     'rainIntensityMin': 0,
#                     'sleetAccumulationAvg': 0,
#                     'sleetAccumulationLweAvg': 0,
#                     'sleetAccumulationLweMax': 0,
#                     'sleetAccumulationLweMin': 0,
#                     'sleetAccumulationLweSum': 0,
#                     'sleetAccumulationMax': 0,
#                     'sleetAccumulationMin': 0,
#                     'sleetIntensityAvg': 0,
#                     'sleetIntensityMax': 0,
#                     'sleetIntensityMin': 0,
#                     'snowAccumulationAvg': 0,
#                     'snowAccumulationLweAvg': 0,
#                     'snowAccumulationLweMax': 0,
#                     'snowAccumulationLweMin': 0,
#                     'snowAccumulationLweSum': 0,
#                     'snowAccumulationMax': 0,
#                     'snowAccumulationMin': 0,
#                     'snowAccumulationSum': 0,
#                     'snowIntensityAvg': 0,
#                     'snowIntensityMax': 0,
#                     'snowIntensityMin': 0,
#                     'sunriseTime': '2025-06-09T04:08:00Z',
#                     'sunsetTime': '2025-06-09T19:53:00Z',
#                     'temperatureApparentAvg': 16.1,
#                     'temperatureApparentMax': 21.2,
#                     'temperatureApparentMin': 11.6,
#                     'temperatureAvg': 16.1,
#                     'temperatureMax': 21.2,
#                     'temperatureMin': 11.6,
#                     'uvHealthConcernAvg': 0,
#                     'uvHealthConcernMax': 1,
#                     'uvHealthConcernMin': 0,
#                     'uvIndexAvg': 1,
#                     'uvIndexMax': 3,
#                     'uvIndexMin': 0,
#                     'visibilityAvg': 16,
#                     'visibilityMax': 16,
#                     'visibilityMin': 16,
#                     'weatherCodeMax': 1001,
#                     'weatherCodeMin': 1001,
#                     'windDirectionAvg': 238,
#                     'windGustAvg': 5.2,
#                     'windGustMax': 9.8,
#                     'windGustMin': 0.1,
#                     'windSpeedAvg': 2.4,
#                     'windSpeedMax': 4.3,
#                     'windSpeedMin': 0
#                 }
#             },
#             {
#                 'time': '2025-06-10T05:00:00Z',
#                 'values': {
#                     'cloudBaseAvg': 0.9,
#                     'cloudBaseMax': 2.3,
#                     'cloudBaseMin': 0,
#                     'cloudCeilingAvg': 3.9,
#                     'cloudCeilingMax': 12.3,
#                     'cloudCeilingMin': 0,
#                     'cloudCoverAvg': 73,
#                     'cloudCoverMax': 100,
#                     'cloudCoverMin': 0,
#                     'dewPointAvg': 12.2,
#                     'dewPointMax': 13.4,
#                     'dewPointMin': 11.3,
#                     'evapotranspirationAvg': 0.101,
#                     'evapotranspirationMax': 0.147,
#                     'evapotranspirationMin': 0.053,
#                     'evapotranspirationSum': 2.428,
#                     'freezingRainIntensityAvg': 0,
#                     'freezingRainIntensityMax': 0,
#                     'freezingRainIntensityMin': 0,
#                     'humidityAvg': 72,
#                     'humidityMax': 94,
#                     'humidityMin': 54,
#                     'iceAccumulationAvg': 0,
#                     'iceAccumulationLweAvg': 0,
#                     'iceAccumulationLweMax': 0,
#                     'iceAccumulationLweMin': 0,
#                     'iceAccumulationLweSum': 0,
#                     'iceAccumulationMax': 0,
#                     'iceAccumulationMin': 0,
#                     'iceAccumulationSum': 0,
#                     'moonriseTime': '2025-06-10T20:14:40Z',
#                     'moonsetTime': '2025-06-10T02:28:28Z',
#                     'precipitationProbabilityAvg': 1,
#                     'precipitationProbabilityMax': 5,
#                     'precipitationProbabilityMin': 0,
#                     'pressureSeaLevelAvg': 1017.73,
#                     'pressureSeaLevelMax': 1020.08,
#                     'pressureSeaLevelMin': 1015.63,
#                     'pressureSurfaceLevelAvg': 1015.21,
#                     'pressureSurfaceLevelMax': 1017.59,
#                     'pressureSurfaceLevelMin': 1013.13,
#                     'rainAccumulationAvg': 0,
#                     'rainAccumulationMax': 0,
#                     'rainAccumulationMin': 0,
#                     'rainAccumulationSum': 0,
#                     'rainIntensityAvg': 0.02,
#                     'rainIntensityMax': 0.3,
#                     'rainIntensityMin': 0,
#                     'sleetIntensityAvg': 0,
#                     'sleetIntensityMax': 0,
#                     'sleetIntensityMin': 0,
#                     'snowAccumulationAvg': 0,
#                     'snowAccumulationLweAvg': 0,
#                     'snowAccumulationLweMax': 0,
#                     'snowAccumulationLweMin': 0,
#                     'snowAccumulationLweSum': 0,
#                     'snowAccumulationMax': 0,
#                     'snowAccumulationMin': 0,
#                     'snowAccumulationSum': 0,
#                     'snowIntensityAvg': 0,
#                     'snowIntensityMax': 0,
#                     'snowIntensityMin': 0,
#                     'sunriseTime': '2025-06-10T04:08:00Z',
#                     'sunsetTime': '2025-06-10T19:54:00Z',
#                     'temperatureApparentAvg': 17.5,
#                     'temperatureApparentMax': 21.5,
#                     'temperatureApparentMin': 12.6,
#                     'temperatureAvg': 17.5,
#                     'temperatureMax': 21.5,
#                     'temperatureMin': 12.6,
#                     'uvHealthConcernAvg': 0,
#                     'uvHealthConcernMax': 1,
#                     'uvHealthConcernMin': 0,
#                     'uvIndexAvg': 1,
#                     'uvIndexMax': 4,
#                     'uvIndexMin': 0,
#                     'visibilityAvg': 16,
#                     'visibilityMax': 16,
#                     'visibilityMin': 16,
#                     'weatherCodeMax': 1001,
#                     'weatherCodeMin': 1001,
#                     'windDirectionAvg': 194,
#                     'windGustAvg': 7.1,
#                     'windGustMax': 14.3,
#                     'windGustMin': 3.1,
#                     'windSpeedAvg': 3.3,
#                     'windSpeedMax': 6.7,
#                     'windSpeedMin': 1.6
#                 }
#             },
#             {
#                 'time': '2025-06-11T05:00:00Z',
#                 'values': {
#                     'cloudBaseAvg': 4.1,
#                     'cloudBaseMax': 11.7,
#                     'cloudBaseMin': 0,
#                     'cloudCeilingAvg': 4.6,
#                     'cloudCeilingMax': 12.2,
#                     'cloudCeilingMin': 0,
#                     'cloudCoverAvg': 68,
#                     'cloudCoverMax': 100,
#                     'cloudCoverMin': 0,
#                     'dewPointAvg': 12.2,
#                     'dewPointMax': 14.3,
#                     'dewPointMin': 10.7,
#                     'evapotranspirationAvg': 0.131,
#                     'evapotranspirationMax': 0.2,
#                     'evapotranspirationMin': 0.053,
#                     'evapotranspirationSum': 3.15,
#                     'freezingRainIntensityAvg': 0,
#                     'freezingRainIntensityMax': 0,
#                     'freezingRainIntensityMin': 0,
#                     'humidityAvg': 68,
#                     'humidityMax': 94,
#                     'humidityMin': 50,
#                     'iceAccumulationAvg': 0,
#                     'iceAccumulationLweAvg': 0,
#                     'iceAccumulationLweMax': 0,
#                     'iceAccumulationLweMin': 0,
#                     'iceAccumulationLweSum': 0,
#                     'iceAccumulationMax': 0,
#                     'iceAccumulationMin': 0,
#                     'iceAccumulationSum': 0,
#                     'moonriseTime': '2025-06-11T21:15:28Z',
#                     'moonsetTime': '2025-06-11T03:04:19Z',
#                     'precipitationProbabilityAvg': 0.6,
#                     'precipitationProbabilityMax': 5,
#                     'precipitationProbabilityMin': 0,
#                     'pressureSeaLevelAvg': 1017.6,
#                     'pressureSeaLevelMax': 1020.26,
#                     'pressureSeaLevelMin': 1013.43,
#                     'pressureSurfaceLevelAvg': 1015.09,
#                     'pressureSurfaceLevelMax': 1017.75,
#                     'pressureSurfaceLevelMin': 1010.99,
#                     'rainAccumulationAvg': 0,
#                     'rainAccumulationMax': 0,
#                     'rainAccumulationMin': 0,
#                     'rainAccumulationSum': 0,
#                     'rainIntensityAvg': 0.01,
#                     'rainIntensityMax': 0.06,
#                     'rainIntensityMin': 0,
#                     'sleetIntensityAvg': 0,
#                     'sleetIntensityMax': 0,
#                     'sleetIntensityMin': 0,
#                     'snowAccumulationAvg': 0,
#                     'snowAccumulationLweAvg': 0,
#                     'snowAccumulationLweMax': 0,
#                     'snowAccumulationLweMin': 0,
#                     'snowAccumulationLweSum': 0,
#                     'snowAccumulationMax': 0,
#                     'snowAccumulationMin': 0,
#                     'snowAccumulationSum': 0,
#                     'snowIntensityAvg': 0,
#                     'snowIntensityMax': 0,
#                     'snowIntensityMin': 0,
#                     'sunriseTime': '2025-06-11T04:08:00Z',
#                     'sunsetTime': '2025-06-11T19:54:00Z',
#                     'temperatureApparentAvg': 18.6,
#                     'temperatureApparentMax': 23,
#                     'temperatureApparentMin': 13.1,
#                     'temperatureAvg': 18.6,
#                     'temperatureMax': 23,
#                     'temperatureMin': 13.1,
#                     'uvHealthConcernAvg': 0,
#                     'uvHealthConcernMax': 1,
#                     'uvHealthConcernMin': 0,
#                     'uvIndexAvg': 1,
#                     'uvIndexMax': 5,
#                     'uvIndexMin': 0,
#                     'visibilityAvg': 16,
#                     'visibilityMax': 16,
#                     'visibilityMin': 16,
#                     'weatherCodeMax': 1001,
#                     'weatherCodeMin': 1001,
#                     'windDirectionAvg': 108,
#                     'windGustAvg': 8.4,
#                     'windGustMax': 10.3,
#                     'windGustMin': 4.3,
#                     'windSpeedAvg': 3.8,
#                     'windSpeedMax': 4.4,
#                     'windSpeedMin': 2
#                 }
#             },
#             {
#                 'time': '2025-06-12T05:00:00Z',
#                 'values': {
#                     'cloudBaseAvg': 3.3,
#                     'cloudBaseMax': 10.4,
#                     'cloudBaseMin': 0,
#                     'cloudCeilingAvg': 3.1,
#                     'cloudCeilingMax': 11,
#                     'cloudCeilingMin': 0,
#                     'cloudCoverAvg': 60,
#                     'cloudCoverMax': 100,
#                     'cloudCoverMin': 0,
#                     'dewPointAvg': 14.2,
#                     'dewPointMax': 17,
#                     'dewPointMin': 11.3,
#                     'evapotranspirationAvg': 0.125,
#                     'evapotranspirationMax': 0.174,
#                     'evapotranspirationMin': 0.077,
#                     'evapotranspirationSum': 3.002,
#                     'freezingRainIntensityAvg': 0,
#                     'freezingRainIntensityMax': 0,
#                     'freezingRainIntensityMin': 0,
#                     'humidityAvg': 73,
#                     'humidityMax': 92,
#                     'humidityMin': 60,
#                     'iceAccumulationAvg': 0,
#                     'iceAccumulationLweAvg': 0,
#                     'iceAccumulationLweMax': 0,
#                     'iceAccumulationLweMin': 0,
#                     'iceAccumulationLweSum': 0,
#                     'iceAccumulationMax': 0,
#                     'iceAccumulationMin': 0,
#                     'iceAccumulationSum': 0,
#                     'moonriseTime': '2025-06-12T22:03:45Z',
#                     'moonsetTime': '2025-06-12T03:52:43Z',
#                     'precipitationProbabilityAvg': 1.7,
#                     'precipitationProbabilityMax': 15,
#                     'precipitationProbabilityMin': 0,
#                     'pressureSeaLevelAvg': 1013.67,
#                     'pressureSeaLevelMax': 1016.49,
#                     'pressureSeaLevelMin': 1011.57,
#                     'pressureSurfaceLevelAvg': 1011.18,
#                     'pressureSurfaceLevelMax': 1013.94,
#                     'pressureSurfaceLevelMin': 1009.08,
#                     'rainAccumulationAvg': 0.02,
#                     'rainAccumulationMax': 0.57,
#                     'rainAccumulationMin': 0,
#                     'rainAccumulationSum': 0.57,
#                     'rainIntensityAvg': 0.02,
#                     'rainIntensityMax': 0.42,
#                     'rainIntensityMin': 0,
#                     'sleetIntensityAvg': 0,
#                     'sleetIntensityMax': 0,
#                     'sleetIntensityMin': 0,
#                     'snowAccumulationAvg': 0,
#                     'snowAccumulationLweAvg': 0,
#                     'snowAccumulationLweMax': 0,
#                     'snowAccumulationLweMin': 0,
#                     'snowAccumulationLweSum': 0,
#                     'snowAccumulationMax': 0,
#                     'snowAccumulationMin': 0,
#                     'snowAccumulationSum': 0,
#                     'snowIntensityAvg': 0,
#                     'snowIntensityMax': 0,
#                     'snowIntensityMin': 0,
#                     'sunriseTime': '2025-06-12T04:08:00Z',
#                     'sunsetTime': '2025-06-12T19:55:00Z',
#                     'temperatureApparentAvg': 19.3,
#                     'temperatureApparentMax': 23.8,
#                     'temperatureApparentMin': 14.6,
#                     'temperatureAvg': 19.3,
#                     'temperatureMax': 23.8,
#                     'temperatureMin': 14.6,
#                     'uvHealthConcernAvg': 0,
#                     'uvHealthConcernMax': 2,
#                     'uvHealthConcernMin': 0,
#                     'uvIndexAvg': 2,
#                     'uvIndexMax': 6,
#                     'uvIndexMin': 0,
#                     'visibilityAvg': 15.62,
#                     'visibilityMax': 16,
#                     'visibilityMin': 6.76,
#                     'weatherCodeMax': 1001,
#                     'weatherCodeMin': 1001,
#                     'windDirectionAvg': 160,
#                     'windGustAvg': 6.3,
#                     'windGustMax': 10.6,
#                     'windGustMin': 2.1,
#                     'windSpeedAvg': 2.9,
#                     'windSpeedMax': 4.5,
#                     'windSpeedMin': 1.2
#                 }
#             },
#             {
#                 'time': '2025-06-13T05:00:00Z',
#                 'values': {
#                     'cloudBaseAvg': 1.6,
#                     'cloudBaseMax': 4,
#                     'cloudBaseMin': 0,
#                     'cloudCeilingAvg': 5,
#                     'cloudCeilingMax': 11.9,
#                     'cloudCeilingMin': 0,
#                     'cloudCoverAvg': 78,
#                     'cloudCoverMax': 100,
#                     'cloudCoverMin': 12,
#                     'dewPointAvg': 15.8,
#                     'dewPointMax': 18.8,
#                     'dewPointMin': 13.3,
#                     'evapotranspirationAvg': 0.141,
#                     'evapotranspirationMax': 0.209,
#                     'evapotranspirationMin': 0.08,
#                     'evapotranspirationSum': 3.375,
#                     'freezingRainIntensityAvg': 0,
#                     'freezingRainIntensityMax': 0,
#                     'freezingRainIntensityMin': 0,
#                     'humidityAvg': 71,
#                     'humidityMax': 96,
#                     'humidityMin': 43,
#                     'iceAccumulationAvg': 0,
#                     'iceAccumulationLweAvg': 0,
#                     'iceAccumulationLweMax': 0,
#                     'iceAccumulationLweMin': 0,
#                     'iceAccumulationLweSum': 0,
#                     'iceAccumulationMax': 0,
#                     'iceAccumulationMin': 0,
#                     'iceAccumulationSum': 0,
#                     'moonriseTime': '2025-06-13T22:40:41Z',
#                     'moonsetTime': '2025-06-13T04:56:57Z',
#                     'precipitationProbabilityAvg': 4.2,
#                     'precipitationProbabilityMax': 30,
#                     'precipitationProbabilityMin': 0,
#                     'pressureSeaLevelAvg': 1015.02,
#                     'pressureSeaLevelMax': 1017.8,
#                     'pressureSeaLevelMin': 1012.81,
#                     'pressureSurfaceLevelAvg': 1012.54,
#                     'pressureSurfaceLevelMax': 1015.37,
#                     'pressureSurfaceLevelMin': 1010.26,
#                     'rainAccumulationAvg': 0.07,
#                     'rainAccumulationMax': 0.55,
#                     'rainAccumulationMin': 0,
#                     'rainAccumulationSum': 1.65,
#                     'rainIntensityAvg': 0,
#                     'rainIntensityMax': 0.02,
#                     'rainIntensityMin': 0,
#                     'sleetIntensityAvg': 0,
#                     'sleetIntensityMax': 0,
#                     'sleetIntensityMin': 0,
#                     'snowAccumulationAvg': 0,
#                     'snowAccumulationLweAvg': 0,
#                     'snowAccumulationLweMax': 0,
#                     'snowAccumulationLweMin': 0,
#                     'snowAccumulationLweSum': 0,
#                     'snowAccumulationMax': 0,
#                     'snowAccumulationMin': 0,
#                     'snowAccumulationSum': 0,
#                     'snowIntensityAvg': 0,
#                     'snowIntensityMax': 0,
#                     'snowIntensityMin': 0,
#                     'sunriseTime': '2025-06-13T04:08:00Z',
#                     'sunsetTime': '2025-06-13T19:55:00Z',
#                     'temperatureApparentAvg': 22,
#                     'temperatureApparentMax': 26.9,
#                     'temperatureApparentMin': 15.3,
#                     'temperatureAvg': 22,
#                     'temperatureMax': 26.9,
#                     'temperatureMin': 15.3,
#                     'uvHealthConcernAvg': 0,
#                     'uvHealthConcernMax': 1,
#                     'uvHealthConcernMin': 0,
#                     'uvIndexAvg': 2,
#                     'uvIndexMax': 5,
#                     'uvIndexMin': 0,
#                     'visibilityAvg': 16,
#                     'visibilityMax': 16,
#                     'visibilityMin': 16,
#                     'weatherCodeMax': 1001,
#                     'weatherCodeMin': 1001,
#                     'windDirectionAvg': 169,
#                     'windGustAvg': 6.1,
#                     'windGustMax': 8.6,
#                     'windGustMin': 2.6,
#                     'windSpeedAvg': 2.7,
#                     'windSpeedMax': 3.7,
#                     'windSpeedMin': 1.1
#                 }
#             },
#             {
#                 'time': '2025-06-14T05:00:00Z',
#                 'values': {
#                     'cloudBaseAvg': 0.9,
#                     'cloudBaseMax': 2.3,
#                     'cloudBaseMin': 0,
#                     'cloudCeilingAvg': 1.4,
#                     'cloudCeilingMax': 8.3,
#                     'cloudCeilingMin': 0,
#                     'cloudCoverAvg': 54,
#                     'cloudCoverMax': 100,
#                     'cloudCoverMin': 0,
#                     'dewPointAvg': 11.7,
#                     'dewPointMax': 14.5,
#                     'dewPointMin': 9.9,
#                     'evapotranspirationAvg': 0.141,
#                     'evapotranspirationMax': 0.215,
#                     'evapotranspirationMin': 0.079,
#                     'evapotranspirationSum': 3.378,
#                     'freezingRainIntensityAvg': 0,
#                     'freezingRainIntensityMax': 0,
#                     'freezingRainIntensityMin': 0,
#                     'humidityAvg': 70,
#                     'humidityMax': 91,
#                     'humidityMin': 49,
#                     'iceAccumulationAvg': 0,
#                     'iceAccumulationLweAvg': 0,
#                     'iceAccumulationLweMax': 0,
#                     'iceAccumulationLweMin': 0,
#                     'iceAccumulationLweSum': 0,
#                     'iceAccumulationMax': 0,
#                     'iceAccumulationMin': 0,
#                     'iceAccumulationSum': 0,
#                     'moonriseTime': '2025-06-14T23:06:06Z',
#                     'moonsetTime': '2025-06-14T06:11:55Z',
#                     'precipitationProbabilityAvg': 0,
#                     'precipitationProbabilityMax': 0,
#                     'precipitationProbabilityMin': 0,
#                     'pressureSeaLevelAvg': 1019.52,
#                     'pressureSeaLevelMax': 1023.16,
#                     'pressureSeaLevelMin': 1014.66,
#                     'pressureSurfaceLevelAvg': 1017.02,
#                     'pressureSurfaceLevelMax': 1020.64,
#                     'pressureSurfaceLevelMin': 1012.18,
#                     'rainAccumulationAvg': 0,
#                     'rainAccumulationMax': 0,
#                     'rainAccumulationMin': 0,
#                     'rainAccumulationSum': 0,
#                     'rainIntensityAvg': 0,
#                     'rainIntensityMax': 0,
#                     'rainIntensityMin': 0,
#                     'sleetIntensityAvg': 0,
#                     'sleetIntensityMax': 0,
#                     'sleetIntensityMin': 0,
#                     'snowAccumulationAvg': 0,
#                     'snowAccumulationLweAvg': 0,
#                     'snowAccumulationLweMax': 0,
#                     'snowAccumulationLweMin': 0,
#                     'snowAccumulationLweSum': 0,
#                     'snowAccumulationMax': 0,
#                     'snowAccumulationMin': 0,
#                     'snowAccumulationSum': 0,
#                     'snowIntensityAvg': 0,
#                     'snowIntensityMax': 0,
#                     'snowIntensityMin': 0,
#                     'sunriseTime': '2025-06-14T04:08:00Z',
#                     'sunsetTime': '2025-06-14T19:56:00Z',
#                     'temperatureApparentAvg': 17.7,
#                     'temperatureApparentMax': 21.4,
#                     'temperatureApparentMin': 12.4,
#                     'temperatureAvg': 17.7,
#                     'temperatureMax': 21.4,
#                     'temperatureMin': 12.4,
#                     'uvHealthConcernAvg': 1,
#                     'uvHealthConcernMax': 1,
#                     'uvHealthConcernMin': 0,
#                     'uvIndexAvg': 2,
#                     'uvIndexMax': 3,
#                     'uvIndexMin': 0,
#                     'visibilityAvg': 16,
#                     'visibilityMax': 16,
#                     'visibilityMin': 16,
#                     'weatherCodeMax': 1001,
#                     'weatherCodeMin': 1001,
#                     'windDirectionAvg': 231,
#                     'windGustAvg': 9.1,
#                     'windGustMax': 13.2,
#                     'windGustMin': 4.3,
#                     'windSpeedAvg': 4.2,
#                     'windSpeedMax': 5.8,
#                     'windSpeedMin': 2.2
#                 }
#             }
#         ]
#     },
#     'location': {'lat': 51.468, 'lon': -0.4551}
# }

# %%
# the list we need to remove the last few elements in:
len(heathrow_5day_data['timelines']['daily'])
# answer = 6, so we need to remove the last 3 - we can just remove last item three times

heathrow_5day_data['timelines']['daily'].pop()
heathrow_5day_data['timelines']['daily'].pop()
heathrow_5day_data['timelines']['daily'].pop()

heathrow_3day_data = heathrow_5day_data['timelines']['daily']
heathrow_3day_data
# Out:
# [{'time': '2025-06-09T05:00:00Z',
#   'values': {'cloudBaseAvg': 1.6,
#    'cloudBaseMax': 6.2,
#    'cloudBaseMin': 0,
#    'cloudCeilingAvg': 4.3,
#    'cloudCeilingMax': 9.7,
#    'cloudCeilingMin': 0,
#    'cloudCoverAvg': 94,
#    'cloudCoverMax': 100,
#    'cloudCoverMin': 34,
#    'dewPointAvg': 10.8,
#    'dewPointMax': 12.3,
#    'dewPointMin': 8.9,
#    'evapotranspirationAvg': 0.157,
#    'evapotranspirationMax': 0.289,
#    'evapotranspirationMin': 0.008,
#    'evapotranspirationSum': 3.756,
#    'freezingRainIntensityAvg': 0,
#    'freezingRainIntensityMax': 0,
#    'freezingRainIntensityMin': 0,
#    'humidityAvg': 72,
#    'humidityMax': 88,
#    'humidityMin': 53,
#    'iceAccumulationAvg': 0,
#    'iceAccumulationLweAvg': 0,
#    'iceAccumulationLweMax': 0,
#    'iceAccumulationLweMin': 0,
#    'iceAccumulationLweSum': 0,
#    'iceAccumulationMax': 0,
#    'iceAccumulationMin': 0,
#    'iceAccumulationSum': 0,
#    'moonriseTime': '2025-06-09T19:04:47Z',
#    'moonsetTime': '2025-06-09T02:05:00Z',
#    'precipitationProbabilityAvg': 0,
#    'precipitationProbabilityMax': 0,
#    'precipitationProbabilityMin': 0,
#    'pressureSeaLevelAvg': 1019.77,
#    'pressureSeaLevelMax': 1022.11,
#    'pressureSeaLevelMin': 1016.32,
#    'pressureSurfaceLevelAvg': 1017.61,
#    'pressureSurfaceLevelMax': 1024.03,
#    'pressureSurfaceLevelMin': 1013.75,
#    'rainAccumulationAvg': 0,
#    'rainAccumulationMax': 0,
#    'rainAccumulationMin': 0,
#    'rainAccumulationSum': 0,
#    'rainIntensityAvg': 0,
#    'rainIntensityMax': 0,
#    'rainIntensityMin': 0,
#    'sleetAccumulationAvg': 0,
#    'sleetAccumulationLweAvg': 0,
#    'sleetAccumulationLweMax': 0,
#    'sleetAccumulationLweMin': 0,
#    'sleetAccumulationLweSum': 0,
#    'sleetAccumulationMax': 0,
#    'sleetAccumulationMin': 0,
#    'sleetIntensityAvg': 0,
#    'sleetIntensityMax': 0,
#    'sleetIntensityMin': 0,
#    'snowAccumulationAvg': 0,
#    'snowAccumulationLweAvg': 0,
#    'snowAccumulationLweMax': 0,
#    'snowAccumulationLweMin': 0,
#    'snowAccumulationLweSum': 0,
#    'snowAccumulationMax': 0,
#    'snowAccumulationMin': 0,
#    'snowAccumulationSum': 0,
#    'snowIntensityAvg': 0,
#    'snowIntensityMax': 0,
#    'snowIntensityMin': 0,
#    'sunriseTime': '2025-06-09T04:08:00Z',
#    'sunsetTime': '2025-06-09T19:53:00Z',
#    'temperatureApparentAvg': 16.1,
#    'temperatureApparentMax': 21.2,
#    'temperatureApparentMin': 11.6,
#    'temperatureAvg': 16.1,
#    'temperatureMax': 21.2,
#    'temperatureMin': 11.6,
#    'uvHealthConcernAvg': 0,
#    'uvHealthConcernMax': 1,
#    'uvHealthConcernMin': 0,
#    'uvIndexAvg': 1,
#    'uvIndexMax': 3,
#    'uvIndexMin': 0,
#    'visibilityAvg': 16,
#    'visibilityMax': 16,
#    'visibilityMin': 16,
#    'weatherCodeMax': 1001,
#    'weatherCodeMin': 1001,
#    'windDirectionAvg': 238,
#    'windGustAvg': 5.2,
#    'windGustMax': 9.8,
#    'windGustMin': 0.1,
#    'windSpeedAvg': 2.4,
#    'windSpeedMax': 4.3,
#    'windSpeedMin': 0}},
#  {'time': '2025-06-10T05:00:00Z',
#   'values': {'cloudBaseAvg': 0.9,
#    'cloudBaseMax': 2.3,
#    'cloudBaseMin': 0,
#    'cloudCeilingAvg': 3.9,
#    'cloudCeilingMax': 12.3,
#    'cloudCeilingMin': 0,
#    'cloudCoverAvg': 73,
#    'cloudCoverMax': 100,
#    'cloudCoverMin': 0,
#    'dewPointAvg': 12.2,
#    'dewPointMax': 13.4,
#    'dewPointMin': 11.3,
#    'evapotranspirationAvg': 0.101,
#    'evapotranspirationMax': 0.147,
#    'evapotranspirationMin': 0.053,
#    'evapotranspirationSum': 2.428,
#    'freezingRainIntensityAvg': 0,
#    'freezingRainIntensityMax': 0,
#    'freezingRainIntensityMin': 0,
#    'humidityAvg': 72,
#    'humidityMax': 94,
#    'humidityMin': 54,
#    'iceAccumulationAvg': 0,
#    'iceAccumulationLweAvg': 0,
#    'iceAccumulationLweMax': 0,
#    'iceAccumulationLweMin': 0,
#    'iceAccumulationLweSum': 0,
#    'iceAccumulationMax': 0,
#    'iceAccumulationMin': 0,
#    'iceAccumulationSum': 0,
#    'moonriseTime': '2025-06-10T20:14:40Z',
#    'moonsetTime': '2025-06-10T02:28:28Z',
#    'precipitationProbabilityAvg': 1,
#    'precipitationProbabilityMax': 5,
#    'precipitationProbabilityMin': 0,
#    'pressureSeaLevelAvg': 1017.73,
#    'pressureSeaLevelMax': 1020.08,
#    'pressureSeaLevelMin': 1015.63,
#    'pressureSurfaceLevelAvg': 1015.21,
#    'pressureSurfaceLevelMax': 1017.59,
#    'pressureSurfaceLevelMin': 1013.13,
#    'rainAccumulationAvg': 0,
#    'rainAccumulationMax': 0,
#    'rainAccumulationMin': 0,
#    'rainAccumulationSum': 0,
#    'rainIntensityAvg': 0.02,
#    'rainIntensityMax': 0.3,
#    'rainIntensityMin': 0,
#    'sleetIntensityAvg': 0,
#    'sleetIntensityMax': 0,
#    'sleetIntensityMin': 0,
#    'snowAccumulationAvg': 0,
#    'snowAccumulationLweAvg': 0,
#    'snowAccumulationLweMax': 0,
#    'snowAccumulationLweMin': 0,
#    'snowAccumulationLweSum': 0,
#    'snowAccumulationMax': 0,
#    'snowAccumulationMin': 0,
#    'snowAccumulationSum': 0,
#    'snowIntensityAvg': 0,
#    'snowIntensityMax': 0,
#    'snowIntensityMin': 0,
#    'sunriseTime': '2025-06-10T04:08:00Z',
#    'sunsetTime': '2025-06-10T19:54:00Z',
#    'temperatureApparentAvg': 17.5,
#    'temperatureApparentMax': 21.5,
#    'temperatureApparentMin': 12.6,
#    'temperatureAvg': 17.5,
#    'temperatureMax': 21.5,
#    'temperatureMin': 12.6,
#    'uvHealthConcernAvg': 0,
#    'uvHealthConcernMax': 1,
#    'uvHealthConcernMin': 0,
#    'uvIndexAvg': 1,
#    'uvIndexMax': 4,
#    'uvIndexMin': 0,
#    'visibilityAvg': 16,
#    'visibilityMax': 16,
#    'visibilityMin': 16,
#    'weatherCodeMax': 1001,
#    'weatherCodeMin': 1001,
#    'windDirectionAvg': 194,
#    'windGustAvg': 7.1,
#    'windGustMax': 14.3,
#    'windGustMin': 3.1,
#    'windSpeedAvg': 3.3,
#    'windSpeedMax': 6.7,
#    'windSpeedMin': 1.6}},
#  {'time': '2025-06-11T05:00:00Z',
#   'values': {'cloudBaseAvg': 4.1,
#    'cloudBaseMax': 11.7,
#    'cloudBaseMin': 0,
#    'cloudCeilingAvg': 4.6,
#    'cloudCeilingMax': 12.2,
#    'cloudCeilingMin': 0,
#    'cloudCoverAvg': 68,
#    'cloudCoverMax': 100,
#    'cloudCoverMin': 0,
#    'dewPointAvg': 12.2,
#    'dewPointMax': 14.3,
#    'dewPointMin': 10.7,
#    'evapotranspirationAvg': 0.131,
#    'evapotranspirationMax': 0.2,
#    'evapotranspirationMin': 0.053,
#    'evapotranspirationSum': 3.15,
#    'freezingRainIntensityAvg': 0,
#    'freezingRainIntensityMax': 0,
#    'freezingRainIntensityMin': 0,
#    'humidityAvg': 68,
#    'humidityMax': 94,
#    'humidityMin': 50,
#    'iceAccumulationAvg': 0,
#    'iceAccumulationLweAvg': 0,
#    'iceAccumulationLweMax': 0,
#    'iceAccumulationLweMin': 0,
#    'iceAccumulationLweSum': 0,
#    'iceAccumulationMax': 0,
#    'iceAccumulationMin': 0,
#    'iceAccumulationSum': 0,
#    'moonriseTime': '2025-06-11T21:15:28Z',
#    'moonsetTime': '2025-06-11T03:04:19Z',
#    'precipitationProbabilityAvg': 0.6,
#    'precipitationProbabilityMax': 5,
#    'precipitationProbabilityMin': 0,
#    'pressureSeaLevelAvg': 1017.6,
#    'pressureSeaLevelMax': 1020.26,
#    'pressureSeaLevelMin': 1013.43,
#    'pressureSurfaceLevelAvg': 1015.09,
#    'pressureSurfaceLevelMax': 1017.75,
#    'pressureSurfaceLevelMin': 1010.99,
#    'rainAccumulationAvg': 0,
#    'rainAccumulationMax': 0,
#    'rainAccumulationMin': 0,
#    'rainAccumulationSum': 0,
#    'rainIntensityAvg': 0.01,
#    'rainIntensityMax': 0.06,
#    'rainIntensityMin': 0,
#    'sleetIntensityAvg': 0,
#    'sleetIntensityMax': 0,
#    'sleetIntensityMin': 0,
#    'snowAccumulationAvg': 0,
#    'snowAccumulationLweAvg': 0,
#    'snowAccumulationLweMax': 0,
#    'snowAccumulationLweMin': 0,
#    'snowAccumulationLweSum': 0,
#    'snowAccumulationMax': 0,
#    'snowAccumulationMin': 0,
#    'snowAccumulationSum': 0,
#    'snowIntensityAvg': 0,
#    'snowIntensityMax': 0,
#    'snowIntensityMin': 0,
#    'sunriseTime': '2025-06-11T04:08:00Z',
#    'sunsetTime': '2025-06-11T19:54:00Z',
#    'temperatureApparentAvg': 18.6,
#    'temperatureApparentMax': 23,
#    'temperatureApparentMin': 13.1,
#    'temperatureAvg': 18.6,
#    'temperatureMax': 23,
#    'temperatureMin': 13.1,
#    'uvHealthConcernAvg': 0,
#    'uvHealthConcernMax': 1,
#    'uvHealthConcernMin': 0,
#    'uvIndexAvg': 1,
#    'uvIndexMax': 5,
#    'uvIndexMin': 0,
#    'visibilityAvg': 16,
#    'visibilityMax': 16,
#    'visibilityMin': 16,
#    'weatherCodeMax': 1001,
#    'weatherCodeMin': 1001,
#    'windDirectionAvg': 108,
#    'windGustAvg': 8.4,
#    'windGustMax': 10.3,
#    'windGustMin': 4.3,
#    'windSpeedAvg': 3.8,
#    'windSpeedMax': 4.4,
#    'windSpeedMin': 2}}]

# %% [markdown]
# #### Question 8: Print the date of each of the 3 forecast days

# %%
for date in heathrow_3day_data:
    print(date['time'])
# Out:
# 2025-06-09T05:00:00Z
# 2025-06-10T05:00:00Z
# 2025-06-11T05:00:00Z

# %% [markdown]
# #### Question 9: Print max temp of each day

# %%
for date in heathrow_3day_data:
    print(f'{date['time']}: {date['values']['temperatureMax']} degrees C')
# Out:
# 2025-06-09T05:00:00Z: 21.2 degrees C
# 2025-06-10T05:00:00Z: 21.5 degrees C
# 2025-06-11T05:00:00Z: 23 degrees C

# %% [markdown]
# #### Question 10: Print only the day with the highest max temp

# %%
hottestday = max(heathrow_3day_data, key=lambda date:date['values']['temperatureMax'])

f"The hottest day is {hottestday['time']}"

# the max function (like the min or sorted function) takes the list of dictionaries heathrow_3day_forecast['forecast']['forecastday'] and finds the dictionary with the largest value for the key ['day']['maxtemp_f']
# hottestday = that dictionary
# but just printing 'hottestday' here would print out the whole dictionary for that hottest day, rather than the value of the hottest day
# so to print the date of the hottest day, we print the key ['date'] for the dictionary hottestday
# Out:
# 'The hottest day is 2025-06-11T05:00:00Z'
